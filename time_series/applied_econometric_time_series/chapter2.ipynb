# %% [markdown]
# # Chapter2 stationary time series models

# %%
library(scales)
library(ggplot2)

# %% [markdown]
# ## problems10
# (1)plot y1(csv/SIM2.csv).is it statinoary time series?

# %%
data<-read.csv("csvs/SIM2.csv",header=T)
head(data)
# Out:
#   X y1       y2       y3
# 1 1  0.60805  3.96768  0.04856
# 2 2 -0.29348 -2.23051  0.14200
# 3 3 -0.68832  1.69602 -0.10089
# 4 4 -0.86596 -1.61072 -0.50346
# 5 5  0.66890  3.79400 -0.50044
# 6 6  0.65094 -4.81795  0.15233

# %%
ggplot(data,aes(x=X,y=y1))+geom_line()+ggtitle("stationary time series?")
# Out:
# plot without title

# %%
acf(data$y1)
pacf(data$y1)
# Out:
# Plot with title "Series  data$y1"
# Plot with title "Series  data$y1"

# %% [markdown]
# ### (2)can you get the same result as described in table 2.2

# %%
library(forecast)
ar1<-arima(x=data$y1,order=c(1,0,0))
print(ar1)
head(residuals(ar1))
checkresiduals(ar1)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Call:
# arima(x = data$y1, order = c(1, 0, 0))
#
# Coefficients:
#          ar1  intercept
#       0.7526    -0.4809
# s.e.  0.0658     0.3610
#
# sigma^2 estimated as 0.8408:  log likelihood = -133.64,  aic = 273.28
# A Time Series:
# [1]  0.7171069 -0.6320848 -0.3484586 -0.2289530  1.4395938  0.2665412
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(1,0,0) with non-zero mean
# Q* = 6.7124, df = 8, p-value = 0.568
#
# Model df: 2.   Total lags used: 10
# plot without title
